# %%
nome_clube = "Santos F C"

elenco = ["Brasao", "Luan", "Arthur", "Neymar", "Gabigol"]
posicoes = ["Goleiro", "Zagueiro","Meia", "Meia", "Atacante"]
total_atletas = len(elenco)

print(f'Bem vindos ao {nome_clube} !')
print(f'Nosso atleta destaque é {elenco[-2]} na posição de {posicoes[3]}')
print(f'O total de atletas é {total_atletas}')
# Out:
# Bem vindos ao Santos F C !
# Nosso atleta destaque é Neymar na posição de Meia
# O total de atletas é 5
