# %% [markdown]
# ### O Conceito Técnico no Futebol
# Na gestão do elenco, além de contratar e substituir,
# o analista precisa lidar com rescisões ou dispensas e
#  também separar setores específicos do time (como a linha defensiva ou o meio-campo).

# %%
# Removendo atletas com .pop() ou .remove():

# .remove("Nome"): busca e remove o atleta pelo próprio nome.


atacantes.remove("Endrick")

# %%
# .pop(indice): dispensa o atleta de uma posição específica da lista. Se usado vazio (.pop()), ele remove automaticamente o último da lista.


dispensado = atacantes.pop(0)  # Remove quem estava no índice 0

# %%
# Fatiamento de Listas (Slicing):

# Para selecionar um grupo de jogadores sem precisar pegá-los um por um, usamos a sintaxe [inicio:fim].

# Atenção: o índice de fim não entra na contagem!

# Pega os índices 0 e 1 (o 2 fica de fora)
dupla_ataque = atacantes[0:2]

# %%
elenco_completo = ["Luan Peres", "Lucas Verissimo", "G. Bomtempo", "Schimidt", "Neymar", "Gabigol"]
meio_campo = elenco_completo[2:4]
elenco_completo.remove("Schimidt")
dispensado = elenco_completo.pop(-1) # .POP REMOVE O INDICE EM ()

print(f'{meio_campo} são os meias da partida')
print(f'Essa é a lista com as baixas {elenco_completo}')
print(len(elenco_completo)," jogadores o elenco possui")
# Out:
# ['G. Bomtempo', 'Schimidt'] são os meias da partida
# Essa é a lista com as baixas ['Luan Peres', 'Lucas Verissimo', 'G. Bomtempo', 'Neymar']
# 4  jogadores o elenco possui
