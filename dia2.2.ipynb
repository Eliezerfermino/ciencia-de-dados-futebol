# %% [markdown]
# O Conceito Técnico no Futebol
# No futebol moderno, o meio-campista dita o ritmo do jogo. Para a comissão técnica, não basta saber quantos passes um volante ou meia deu: precisamos medir a precisão e a capacidade de quebrar linhas com passes decisivos (passes que geram finalização imediata).
#
# Para isso, usamos dicionários para registrar os volumes absolutos e derivamos as métricas de eficiência:

# %% [markdown]
# Taxa de Acerto de Passes (%):Mede a segurança na posse de bola:$$\text{acerto\_passes} = \left(\frac{\text{passes\_certos}}{\text{passes\_tentados}}\right) \times 100$$Índice de Criação (Passes Decisivos por Jogo):Avalia a média de chances criadas por partida:$$\text{chances\_por\_jogo} = \frac{\text{passes\_decisivos}}{\text{jogos}}$$

# %%
# Atualização da Ficha:

# Adicionamos as novas métricas calculadas diretamente no dicionário do atleta:

meia["acerto_passes"] = taxa_calculada
meia["chances_por_jogo"] = chances_calculadas

# %%
ficha_meia = {
    "Nome": "Benjamín Rollheiser",
    "Jogos": 46,
    "passes_tentados": 659,
    "passes_certos": 337,
    "passes_decisivos": 123
}
acerto_passes = ficha_meia["passes_certos"] / ficha_meia["passes_tentados"] * 100
ficha_meia["acerto_passes"] = acerto_passes

chances_por_jogo = ficha_meia["passes_decisivos"] / ficha_meia["Jogos"]
ficha_meia["chances_por_jogo"] = chances_por_jogo

print(f'O jogador {ficha_meia["Nome"]} jogou até o momento {ficha_meia["Jogos"]} partidas')
print(f'A porcentagem de acerto de passes é {ficha_meia["acerto_passes"]:.2f} % ')
print(f'A media de chances criadas foram {chances_por_jogo:.2f}')
# Out:
# O jogador Benjamín Rollheiser jogou até o momento 46 partidas
# A porcentagem de acerto de passes é 51.14 %
# A media de chances criadas foram 2.67

# %%
ficha_meia
# Out:
# {'Nome': 'Benjamín Rollheiser',
#  'Jogos': 46,
#  'passes_tentados': 659,
#  'passes_certos': 337,
#  'passes_decisivos': 123,
#  'acerto_passes': 51.138088012139605,
#  'chances_por_jogo': 2.6739130434782608}
