# %%
nome_clube = "Santos Futebol CLube"
elenco_ataque = [
    {"nome": "Gabriel Barbosa", "minutos": 856, "chutes_gol": 438, "gols": 20},
    {"nome": "Neymar Junior", "minutos": 1050, "chutes_gol": 689, "gols": 55},
    {"nome": "Thaciano", "minutos": 678, "chutes_gol": 215, "gols": 11}
]
total_avaliados = len(elenco_ataque)
print("Bem vindos ao", nome_clube, "\nnesse momento estamos avaliando", total_avaliados, "atletas\n")

for atleta in elenco_ataque:
    minutos_por_gol = atleta["minutos"] / atleta["gols"]
    taxa_conversão = atleta["gols"] / atleta["chutes_gol"] * 100
    
    print(f'O atleta {atleta["nome"]} precisou de {minutos_por_gol:.1f} minutos para fazer um GOL \nA sua taxa de conversão é de {taxa_conversão:.2f} %\n')
# Out:
# Bem vindos ao Santos Futebol CLube
# nesse momento estamos avaliando 3 atletas
#
# O atleta Gabriel Barbosa precisou de 42.8 minutos para fazer um GOL
# A sua taxa de conversão é de 4.57 %
#
# O atleta Neymar Junior precisou de 19.1 minutos para fazer um GOL
# A sua taxa de conversão é de 7.98 %
#
# O atleta Thaciano precisou de 61.6 minutos para fazer um GOL
# A sua taxa de conversão é de 5.12 %
