# %%
#Variável: Pense na variável como a camisa de um jogador ou a prancheta do técnico. Ela guarda uma informação com um nome que você escolhe.

clube = "Real Madrid" #guarda um texto (string).

titulares_campo = 11 #guarda um número inteiro (integer).

# %%
# Lista (list): É a sua lista de convocados ou a súmula do jogo. Ela armazena vários itens em ordem dentro de colchetes [], separados por vírgulas.

atacantes = ["Vinicius Jr", "Rodrygo", "Mbappé"]

# %%
# Função len() (Comprimento do Elenco): Abreviação de length. Serve para contar quantos elementos existem 
# dentro da lista (quantos jogadores estão relacionados).

total_atacantes = len(atacantes)  # Retorna 3

# %%
nome_clube = "Santos Futebol Clube"
elenco = ["Brasão", "Luan Peres", "Rodinei", "G. Bomtempo", "Neymar"]
posicoes = ["Goleiro", "Zagueiro", "L. Direita", "Meia", "Atacante"]
total_atletas = len(elenco)

print(f'Seja bem vindo ao {nome_clube}')
print(f'Jogador: {elenco[0]}, posição: {posicoes[0]}')
print(f'Total de atletas: {total_atletas}')
# Out:
# Seja bem vindo ao Santos Futebol Clube
# Jogador: Brasão, posição: Goleiro
# Total de atletas: 5

# %%
banco_reservas = ["Neymar", "Arthur", "Lima"]
print(banco_reservas)

banco_reservas.append("Rodinei")
banco_reservas[0] = "Barreal"

print(f'{banco_reservas} foi adicionado o atleta {banco_reservas[0]}')
# Out:
# ['Neymar', 'Arthur', 'Lima']
# ['Barreal', 'Arthur', 'Lima', 'Rodinei'] foi adicionado o atleta Barreal
