# %% [markdown]
# # ⚽ Semana 1: Fundamentos de Python para Análise de Dados no Futebol
# **Projeto:** Relatório Automatizado de Eficiência Ofensiva
# **Ferramentas:** Python Puro, Google Colab
#
# ### 📌 Objetivo do Script:
# Processar métricas de volume de jogo (minutos jogados) e conversão (gols marcados) de um elenco de ataque, calculando automaticamente a taxa de minutos necessários para marcar cada gol e classificando os atletas por faixas de desempenho tático.
#
# ### 🧠 Conceitos Aplicados:
# - Estruturação de dados com listas e dicionários.
# - Modularização e reutilização de código com funções (`def`).
# - Automação de processamento em lote com laço `for`.
# - Regras de decisão e filtros de status com `if / elif / else`.
# - Formatação de relatórios com f-strings.

# %%
def calcular_minutos_por_gol(minutos, gols):
    resultado = minutos / gols
    return resultado

elenco_ataque = len[
    {"nome": "Jogador A", "minutos": 900, "gols": 32},
    {"nome": "Jogador B", "minutos": 800, "gols": 28},
    {"nome": "Jogador C", "minutos": 846, "gols": 15},
    {"nome": "Jogador C", "minutos": 768, "gols": 11},
    {"nome": "Jogador C", "minutos": 498, "gols": 9},
    {"nome": "Jogador C", "minutos": 900, "gols": 7},
    {"nome": "Jogador C", "minutos": 800, "gols": 18},
    {"nome": "Jogador C", "minutos": 900, "gols": 21},
    {"nome": "Jogador C", "minutos": 359, "gols": 16},
    {"nome": "Jogador C", "minutos": 135, "gols": 7}
]

for jogador in elenco_ataque:
    minutos_por_gol = calcular_minutos_por_gol(jogador["minutos="], jogador["gols"])
